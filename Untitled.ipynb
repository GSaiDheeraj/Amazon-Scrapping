# %%
from autoscraper import AutoScraper

# %%
amazon_url="https://www.amazon.in/s?k=iphones"

wanted_list=['₹49,900', 'New Apple iPhone 11 (64GB) - Black']

# %%
scraper=AutoScraper()
result=scraper.build(amazon_url,wanted_list)
print(result)
# Out:
# ['₹49,900', '₹54,900', '₹68,999', '₹84,900', '₹1,09,999', '₹1,29,900', '₹63,999', '₹79,900', '₹70,900', '₹59,900', '₹47,999', '₹52,900', 'New Apple iPhone 11 (64GB) - Black', 'New Apple iPhone 12 (128GB) - Black', 'New Apple iPhone 12 Pro Max (128GB) - Pacific Blue', 'New Apple iPhone 12 (128GB) - Blue', 'New Apple iPhone 12 (64GB) - Black', 'New Apple iPhone 11 (64GB) - White', 'New Apple iPhone 11 (64GB) - Purple', 'New Apple iPhone 12 (128GB) - Purple', 'New Apple iPhone 11 (128GB) - White', 'New Apple iPhone 11 (128GB) - (Product) RED', 'New Apple iPhone 11 (64GB) - Green', 'New Apple iPhone 11 (64GB) - (Product) RED', 'New Apple iPhone 11 (128GB) - Purple', 'New Apple iPhone 12 (64GB) - Blue', 'New Apple iPhone XR (128GB) - Black']

# %%
scraper.get_result_similar(amazon_url,grouped=True)
# Out:
# {'rule_lkg5': ['₹49,900',
#   '₹54,900',
#   '₹68,999',
#   '₹84,900',
#   '₹1,09,999',
#   '₹1,29,900',
#   '₹68,999',
#   '₹84,900',
#   '₹63,999',
#   '₹79,900',
#   '₹49,900',
#   '₹54,900',
#   '₹49,900',
#   '₹54,900',
#   '₹70,900',
#   '₹84,900',
#   '₹54,900',
#   '₹59,900',
#   '₹54,900',
#   '₹59,900',
#   '₹49,900',
#   '₹54,900',
#   '₹49,900',
#   '₹54,900',
#   '₹54,900',
#   '₹59,900',
#   '₹63,999',
#   '₹79,900',
#   '₹47,999',
#   '₹52,900'],
#  'rule_nwvz': ['₹49,900',
#   '₹54,900',
#   '₹68,999',
#   '₹84,900',
#   '₹1,09,999',
#   '₹1,29,900',
#   '₹68,999',
#   '₹84,900',
#   '₹63,999',
#   '₹79,900',
#   '₹49,900',
#   '₹54,900',
#   '₹49,900',
#   '₹54,900',
#   '₹70,900',
#   '₹84,900',
#   '₹54,900',
#   '₹59,900',
#   '₹54,900',
#   '₹59,900',
#   '₹49,900',
#   '₹54,900',
#   '₹49,900',
#   '₹54,900',
#   '₹54,900',
#   '₹59,900',
#   '₹63,999',
#   '₹79,900',
#   '₹47,999',
#   '₹52,900'],
#  'rule_mnm2': ['₹49,900',
#   '₹54,900',
#   '₹68,999',
# ...

# %%
scraper.set_rule_aliases({'rule_01kd':'Title','rule_lkg5':'Price'})
scraper.keep_rules(['rule_01kd','rule_lkg5'])
scraper.save('amazon-search')

# %%
results=scraper.get_result_similar('https://www.amazon.in/s?k=mi+phones+under+15000',group_by_alias=True)

# %%
results
# Out:
# {'Price': ['₹6,999',
#   '₹8,499',
#   '₹13,999',
#   '₹15,999',
#   '₹9,499',
#   '₹10,999',
#   '₹9,499',
#   '₹10,999',
#   '₹10,499',
#   '₹11,999',
#   '₹6,999',
#   '₹6,999',
#   '₹13,499',
#   '₹16,999',
#   '₹6,999',
#   '₹8,499',
#   '₹11,499',
#   '₹13,999',
#   '₹7,999',
#   '₹9,499',
#   '₹6,990',
#   '₹13,999',
#   '₹15,999',
#   '₹9,499',
#   '₹10,999',
#   '₹12,167',
#   '₹17,499'],
#  'Title': ['Redmi 9A (Nature Green, 2GB RAM, 32GB Storage) | 2GHz Octa-core Helio G25 Processor | 5000 mAh Battery',
#   'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage) -Amoled Dot Display | 48MP Sony Sensor IMX582 | Snapdragon 678 Processor',
#   'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) | 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9 Prime (Mint Green, 4GB RAM, 64GB Storage)- Full HD+ Display & AI Quad Camera',
# ...
